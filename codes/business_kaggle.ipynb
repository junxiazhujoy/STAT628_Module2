# %%
import json
import pandas as pd
import numpy as np
import re
from pandas import DataFrame

# %%
data = [] 
for line in open('business_test.json', 'r'): 
    data.append(json.loads(line))

# %%
dat = data

# %%
#pd.DataFrame.from_dict(dat)

# %%
def fun(KeyString,Diction,newlist):
    if '{' not in str(Diction[KeyString]):
            newlist[KeyString]=str(Diction[KeyString])
    else:
        d=eval(str(Diction[KeyString]))
        for k in d.keys():
            fun(k,d,newlist)

for i in range(len(dat)):#len(dat)  
    attri=dat[i]['attributes']
    if attri!=None:
        newlist={}
        for k in attri.keys():
            fun(k,attri,newlist) 
    dat[i]['attributes_clean']=newlist

#TODO: cat the names together

# %%
AllAttributes=[x['attributes_clean'] for x in dat] #a list of dictionaries
#transform into one dictionary
attridf=pd.DataFrame.from_dict(AllAttributes)
#attridf

# %%
for i in range(len(attridf['Alcohol'])):
    if str(attridf['Alcohol'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['Alcohol'][i]=str(eval(strinfo.sub('\'',str(attridf['Alcohol'][i]))))
    elif str(attridf['Alcohol'][i]).startswith('\''):
            attridf['Alcohol'][i] = str(eval(attridf['Alcohol'][i]))

for i in range(len(attridf['RestaurantsAttire'])):
    if str(attridf['RestaurantsAttire'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['RestaurantsAttire'][i]=str(eval(strinfo.sub('\'',str(attridf['RestaurantsAttire'][i]))))
    elif str(attridf['RestaurantsAttire'][i]).startswith('\''):
            attridf['RestaurantsAttire'][i] = str(eval(attridf['RestaurantsAttire'][i]))
        
for i in range(len(attridf['NoiseLevel'])):
    if str(attridf['NoiseLevel'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['NoiseLevel'][i]=str(eval(strinfo.sub('\'',str(attridf['NoiseLevel'][i]))))
    elif str(attridf['NoiseLevel'][i]).startswith('\''):
        attridf['NoiseLevel'][i] = str(eval(attridf['NoiseLevel'][i]))
        
for i in range(len(attridf['WiFi'])):
    if str(attridf['WiFi'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['WiFi'][i]=str(eval(strinfo.sub('\'',str(attridf['WiFi'][i]))))
    elif str(attridf['WiFi'][i]).startswith('\''):
        attridf['WiFi'][i] = str(eval(attridf['WiFi'][i]))
        
for i in range(len(attridf['BYOBCorkage'])):
    if str(attridf['BYOBCorkage'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['BYOBCorkage'][i]=str(eval(strinfo.sub('\'',str(attridf['BYOBCorkage'][i]))))
    elif str(attridf['BYOBCorkage'][i]).startswith('\''):
        attridf['BYOBCorkage'][i] = str(eval(attridf['BYOBCorkage'][i]))
        
for i in range(len(attridf['Smoking'])):
    if str(attridf['Smoking'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['Smoking'][i]=str(eval(strinfo.sub('\'',str(attridf['Smoking'][i]))))
    elif str(attridf['Smoking'][i]).startswith('\''):
        attridf['Smoking'][i] = str(eval(attridf['Smoking'][i]))        
        
for i in range(len(attridf['AgesAllowed'])):
    if str(attridf['AgesAllowed'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['AgesAllowed'][i]=str(eval(strinfo.sub('\'',str(attridf['AgesAllowed'][i]))))
    elif str(attridf['AgesAllowed'][i]).startswith('\''):
        attridf['AgesAllowed'][i] = str(eval(attridf['AgesAllowed'][i]))
        
for i in range(len(attridf['AgesAllowed'])):
    if str(attridf['AgesAllowed'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['AgesAllowed'][i]=str(eval(strinfo.sub('\'',str(attridf['AgesAllowed'][i]))))
    elif str(attridf['AgesAllowed'][i]).startswith('\''):
        attridf['AgesAllowed'][i] = str(eval(attridf['AgesAllowed'][i]))

# %%
#TODO:NaN change to None.
#ColumnNames=attridf.columns
'''
for i in ColumnNames:
    x for x in attridf[[i]]
'''
isNaN=pd.isnull(attridf)
attridf[pd.isnull(attridf)]='unknown'
#attridf

# %%
#Add Business ID in the data frame
businessIDs=[x['business_id'] for x in dat]
attridf['business_id']=businessIDs
attridf
# Out:
#       AcceptsInsurance AgesAllowed   Alcohol Ambience     BYOB  BYOBCorkage  \
# 0              unknown     unknown  full_bar  unknown  unknown      unknown
# 1              unknown     unknown   unknown  unknown  unknown      unknown
# 2              unknown     unknown   unknown  unknown  unknown      unknown
# 3              unknown     unknown   unknown  unknown  unknown      unknown
# 4              unknown     unknown   unknown  unknown  unknown      unknown
# 5              unknown     unknown  full_bar  unknown  unknown      unknown
# 6              unknown     unknown  full_bar  unknown  unknown      unknown
# 7              unknown     unknown   unknown  unknown  unknown      unknown
# 8              unknown     unknown   unknown  unknown  unknown      unknown
# 9              unknown     unknown   unknown  unknown  unknown      unknown
# 10             unknown     unknown   unknown  unknown  unknown      unknown
# 11             unknown     unknown  full_bar  unknown  unknown      unknown
# 12             unknown     unknown   unknown  unknown  unknown      unknown
# 13             unknown     unknown   unknown  unknown  unknown      unknown
# 14             unknown     unknown  full_bar  unknown  unknown      unknown
# 15             unknown     unknown   unknown  unknown  unknown      unknown
# 16             unknown     unknown      none  unknown  unknown      unknown
# 17             unknown     unknown  full_bar     None  unknown      unknown
# 18             unknown     unknown   unknown  unknown  unknown      unknown
# 19             unknown     unknown   unknown  unknown  unknown      unknown
# 20             unknown     unknown      none  unknown  unknown      unknown
# 21             unknown     unknown   unknown  unknown  unknown      unknown
# 22             unknown     unknown   unknown  unknown  unknown      unknown
# 23             unknown     unknown   unknown  unknown  unknown      unknown
# 24             unknown     unknown   unknown  unknown  unknown      unknown
# 25             unknown     unknown   unknown  unknown  unknown      unknown
# 26             unknown     unknown      none  unknown  unknown      unknown
# 27             unknown     unknown  full_bar  unknown  unknown      unknown
# 28             unknown     unknown  full_bar  unknown  unknown  yes_corkage
# 29             unknown     unknown  full_bar  unknown  unknown  yes_corkage
# ...                ...         ...       ...      ...      ...          ...
# 37970          unknown     unknown   unknown  unknown  unknown      unknown
# 37971          unknown     unknown   unknown  unknown  unknown      unknown
# 37972          unknown     unknown  full_bar  unknown  unknown      unknown
# 37973          unknown     unknown  full_bar  unknown  unknown      unknown
# 37974          unknown     unknown  full_bar  unknown  unknown      unknown
# 37975          unknown     unknown   unknown  unknown  unknown      unknown
# 37976          unknown     unknown      none  unknown  unknown      unknown
# 37977          unknown     unknown   unknown  unknown  unknown      unknown
# 37978          unknown     unknown      none  unknown  unknown      unknown
# 37979          unknown     unknown      none  unknown  unknown      unknown
# 37980          unknown     unknown  full_bar  unknown  unknown      unknown
# 37981          unknown     unknown      none  unknown  unknown      unknown
# 37982          unknown     unknown  full_bar  unknown  unknown      unknown
# 37983          unknown     unknown   unknown  unknown  unknown      unknown
# 37984          unknown     unknown   unknown  unknown  unknown      unknown
# 37985          unknown     unknown   unknown  unknown  unknown      unknown
# 37986          unknown     unknown  full_bar  unknown  unknown      unknown
# 37987          unknown     unknown   unknown  unknown  unknown      unknown
# 37988          unknown     unknown   unknown  unknown  unknown      unknown
# 37989          unknown     unknown      none  unknown  unknown      unknown
# 37990          unknown     unknown   unknown  unknown  unknown      unknown
# 37991          unknown     unknown  full_bar  unknown  unknown      unknown
# 37992          unknown     unknown   unknown  unknown  unknown      unknown
# 37993          unknown     unknown   unknown  unknown  unknown      unknown
# 37994          unknown     unknown   unknown  unknown  unknown      unknown
# 37995          unknown     unknown  full_bar  unknown  unknown      unknown
# 37996          unknown     unknown   unknown  unknown  unknown      unknown
# 37997          unknown     unknown   unknown  unknown  unknown      unknown
# 37998          unknown     unknown   unknown  unknown  unknown      unknown
# 37999          unknown     unknown   unknown  unknown  unknown      unknown
#
#       BestNights BikeParking BusinessAcceptsBitcoin  \
# 0        unknown       False                unknown
# 1        unknown     unknown                unknown
# 2        unknown     unknown                unknown
# 3        unknown        True                unknown
# 4        unknown        True                unknown
# 5        unknown     unknown                unknown
# 6        unknown     unknown                unknown
# 7        unknown        True                unknown
# 8        unknown     unknown                unknown
# 9        unknown     unknown                unknown
# 10       unknown     unknown                unknown
# 11       unknown       False                   True
# 12       unknown       False                unknown
# 13       unknown       False                unknown
# 14       unknown        True                unknown
# 15       unknown       False                  False
# 16       unknown        True                unknown
# 17       unknown        True                unknown
# 18       unknown       False                unknown
# 19       unknown       False                unknown
# 20       unknown        True                unknown
# 21       unknown     unknown                unknown
# 22       unknown     unknown                unknown
# 23       unknown        True                unknown
# 24       unknown       False                  False
# 25       unknown       False                  False
# 26       unknown        True                unknown
# 27       unknown        True                  False
# 28       unknown       False                unknown
# 29       unknown       False                unknown
# ...          ...         ...                    ...
# 37970    unknown        True                unknown
# 37971    unknown        True                unknown
# 37972    unknown        True                  False
# 37973    unknown        True                  False
# 37974    unknown        True                  False
# 37975    unknown        True                unknown
# 37976    unknown       False                unknown
# 37977    unknown        True                unknown
# 37978    unknown       False                unknown
# 37979    unknown       False                unknown
# 37980    unknown       False                unknown
# 37981    unknown        True                unknown
# 37982    unknown       False                unknown
# 37983    unknown     unknown                unknown
# 37984    unknown     unknown                unknown
# 37985    unknown        True                unknown
# 37986    unknown        True                unknown
# 37987    unknown     unknown                  False
# 37988    unknown     unknown                unknown
# 37989    unknown        True                  False
# 37990    unknown       False                unknown
# 37991    unknown     unknown                unknown
# 37992    unknown     unknown                unknown
# 37993    unknown     unknown                unknown
# 37994    unknown     unknown                unknown
# 37995    unknown        True                unknown
# 37996    unknown     unknown                unknown
# 37997    unknown     unknown                unknown
# 37998    unknown        True                unknown
# 37999    unknown        True                unknown
#
#       BusinessAcceptsCreditCards     ...       trendy  tuesday  upscale  \
# 0                        unknown     ...        False  unknown    False
# 1                        unknown     ...      unknown  unknown  unknown
# 2                           True     ...      unknown  unknown  unknown
# 3                           True     ...      unknown  unknown  unknown
# 4                        unknown     ...      unknown  unknown  unknown
# 5                           True     ...      unknown  unknown  unknown
# 6                           True     ...      unknown  unknown  unknown
# 7                           True     ...      unknown  unknown  unknown
# 8                        unknown     ...      unknown  unknown  unknown
# 9                           True     ...      unknown  unknown  unknown
# 10                          True     ...      unknown  unknown  unknown
# 11                          True     ...        False  unknown    False
# 12                          True     ...      unknown  unknown  unknown
# 13                          True     ...      unknown  unknown  unknown
# 14                          True     ...        False  unknown    False
# 15                          True     ...      unknown  unknown  unknown
# 16                       unknown     ...        False  unknown    False
# 17                       unknown     ...      unknown  unknown  unknown
# 18                          True     ...      unknown  unknown  unknown
# 19                          True     ...      unknown  unknown  unknown
# 20                       unknown     ...        False  unknown    False
# 21                          True     ...      unknown  unknown  unknown
# 22                       unknown     ...      unknown  unknown  unknown
# 23                       unknown     ...      unknown  unknown  unknown
# 24                          True     ...      unknown  unknown  unknown
# 25                          True     ...      unknown  unknown  unknown
# 26                       unknown     ...        False  unknown    False
# 27                          True     ...        False  unknown    False
# 28                          True     ...      unknown  unknown  unknown
# 29                          True     ...      unknown  unknown  unknown
# ...                          ...     ...          ...      ...      ...
# 37970                      False     ...      unknown  unknown  unknown
# 37971                      False     ...      unknown  unknown  unknown
# 37972                       True     ...        False  unknown    False
# 37973                       True     ...        False  unknown    False
# 37974                       True     ...        False  unknown    False
# 37975                       True     ...      unknown  unknown  unknown
# 37976                    unknown     ...        False  unknown    False
# 37977                    unknown     ...      unknown  unknown  unknown
# 37978                       True     ...      unknown  unknown  unknown
# 37979                       True     ...      unknown  unknown  unknown
# 37980                    unknown     ...        False  unknown    False
# 37981                       True     ...        False  unknown    False
# 37982                       True     ...        False  unknown    False
# 37983                    unknown     ...      unknown  unknown  unknown
# 37984                    unknown     ...      unknown  unknown  unknown
# 37985                    unknown     ...      unknown  unknown  unknown
# 37986                    unknown     ...        False  unknown    False
# 37987                      False     ...      unknown  unknown  unknown
# 37988                       True     ...      unknown  unknown  unknown
# 37989                       True     ...        False  unknown    False
# 37990                      False     ...      unknown  unknown  unknown
# 37991                    unknown     ...      unknown  unknown  unknown
# 37992                       True     ...      unknown  unknown  unknown
# 37993                       True     ...      unknown  unknown  unknown
# 37994                       True     ...      unknown  unknown  unknown
# 37995                    unknown     ...        False  unknown    False
# 37996                       True     ...      unknown  unknown  unknown
# 37997                       True     ...      unknown  unknown  unknown
# 37998                       True     ...      unknown  unknown  unknown
# 37999                    unknown     ...      unknown  unknown  unknown
#
#          valet validated    vegan vegetarian    video wednesday business_id
# 0        False     False  unknown    unknown  unknown   unknown      141184
# 1        False     False  unknown    unknown  unknown   unknown      148476
# 2        False     False  unknown    unknown  unknown   unknown       86835
# 3        False     False  unknown    unknown  unknown   unknown      116708
# 4        False     False  unknown    unknown  unknown   unknown       59216
# 5        False     False  unknown    unknown  unknown   unknown        8159
# 6        False     False  unknown    unknown  unknown   unknown       78312
# 7        False     False  unknown    unknown  unknown   unknown      155769
# 8      unknown   unknown  unknown    unknown  unknown   unknown       99492
# 9      unknown   unknown  unknown    unknown  unknown   unknown       12721
# 10     unknown   unknown  unknown    unknown  unknown   unknown      136258
# 11       False      True  unknown    unknown  unknown   unknown      187446
# 12       False     False  unknown    unknown  unknown   unknown      191658
# 13       False     False  unknown    unknown  unknown   unknown      124093
# 14       False     False  unknown    unknown  unknown   unknown      133075
# 15       False     False  unknown    unknown  unknown   unknown      174437
# 16       False     False  unknown    unknown  unknown   unknown       36105
# 17     unknown   unknown  unknown    unknown  unknown   unknown       56907
# 18       False     False  unknown    unknown  unknown   unknown      127442
# 19       False     False  unknown    unknown  unknown   unknown      182557
# 20       False     False  unknown    unknown  unknown   unknown      102800
# 21       False     False  unknown    unknown  unknown   unknown       23139
# 22     unknown   unknown  unknown    unknown  unknown   unknown       97908
# 23       False     False  unknown    unknown  unknown   unknown      101349
# 24       False     False  unknown    unknown  unknown   unknown      104706
# 25       False     False  unknown    unknown  unknown   unknown       84525
# 26       False     False  unknown    unknown  unknown   unknown       51307
# 27       False     False  unknown    unknown  unknown   unknown      118321
# 28        True     False  unknown    unknown  unknown   unknown       11267
# 29        True     False  unknown    unknown  unknown   unknown       42336
# ...        ...       ...      ...        ...      ...       ...         ...
# 37970    False     False  unknown    unknown  unknown   unknown       21916
# 37971    False     False  unknown    unknown  unknown   unknown       44664
# 37972     True     False  unknown    unknown  unknown   unknown       36414
# 37973     True     False  unknown    unknown  unknown   unknown       20185
# 37974     True     False  unknown    unknown  unknown   unknown      107129
# 37975    False     False  unknown    unknown  unknown   unknown      139083
# 37976  unknown   unknown  unknown    unknown  unknown   unknown       90678
# 37977    False     False  unknown    unknown  unknown   unknown      188316
# 37978    False     False  unknown    unknown  unknown   unknown       43976
# 37979    False     False  unknown    unknown  unknown   unknown      114529
# 37980    False     False  unknown    unknown  unknown   unknown      133929
# 37981    False     False  unknown    unknown  unknown   unknown      171719
# 37982    False     False  unknown    unknown  unknown   unknown       20524
# 37983  unknown   unknown  unknown    unknown  unknown   unknown       55736
# 37984  unknown   unknown  unknown    unknown  unknown   unknown      150949
# 37985  unknown   unknown  unknown    unknown  unknown   unknown       64795
# 37986    False     False  unknown    unknown  unknown   unknown      112461
# 37987  unknown   unknown  unknown    unknown  unknown   unknown       62368
# 37988  unknown   unknown  unknown    unknown  unknown   unknown      132384
# 37989    False     False  unknown    unknown  unknown   unknown       20536
# 37990    False     False  unknown    unknown  unknown   unknown      150258
# 37991    False     False  unknown    unknown  unknown   unknown      142523
# 37992  unknown   unknown  unknown    unknown  unknown   unknown      125188
# 37993  unknown   unknown  unknown    unknown  unknown   unknown      172653
# 37994  unknown   unknown  unknown    unknown  unknown   unknown      156574
# 37995    False     False  unknown    unknown  unknown   unknown       16647
# 37996  unknown   unknown  unknown    unknown  unknown   unknown      176728
# 37997  unknown   unknown  unknown    unknown  unknown   unknown      118919
# 37998    False     False  unknown    unknown  unknown   unknown       82935
# 37999    False     False  unknown    unknown  unknown   unknown      153674
#
# [38000 rows x 88 columns]

# %%
DataFrame.to_csv(attridf,"business_kaggle.csv",index=False)
