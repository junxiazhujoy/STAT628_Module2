# %%
import json
import pandas as pd
import numpy as np
import re
from pandas import DataFrame
import copy

# %%
data = [] 
for line in open('business_train.json', 'r'): 
    data.append(json.loads(line))

# %%
dat = data

# %%
#pd.DataFrame.from_dict(dat)

# %%
def fun(KeyString,Diction,newlist):
    if '{' not in str(Diction[KeyString]):
            newlist[KeyString]=str(Diction[KeyString])
    else:
        d=eval(str(Diction[KeyString]))
        for k in d.keys():
            fun(k,d,newlist)

for i in range(len(dat)):#len(dat)  
    attri=dat[i]['attributes']
    if attri!=None:
        newlist={}
        for k in attri.keys():
            fun(k,attri,newlist) 
    dat[i]['attributes_clean']=newlist

#TODO: cat the names together

# %%
AllAttributes=[x['attributes_clean'] for x in dat] #a list of dictionaries
#transform into one dictionary
attridf=pd.DataFrame.from_dict(AllAttributes)
#attridf

# %%
for i in range(len(attridf['Alcohol'])):
    if str(attridf['Alcohol'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['Alcohol'][i]=str(eval(strinfo.sub('\'',str(attridf['Alcohol'][i]))))
    elif str(attridf['Alcohol'][i]).startswith('\''):
            attridf['Alcohol'][i] = str(eval(attridf['Alcohol'][i]))

for i in range(len(attridf['RestaurantsAttire'])):
    if str(attridf['RestaurantsAttire'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['RestaurantsAttire'][i]=str(eval(strinfo.sub('\'',str(attridf['RestaurantsAttire'][i]))))
    elif str(attridf['RestaurantsAttire'][i]).startswith('\''):
            attridf['RestaurantsAttire'][i] = str(eval(attridf['RestaurantsAttire'][i]))
        
for i in range(len(attridf['NoiseLevel'])):
    if str(attridf['NoiseLevel'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['NoiseLevel'][i]=str(eval(strinfo.sub('\'',str(attridf['NoiseLevel'][i]))))
    elif str(attridf['NoiseLevel'][i]).startswith('\''):
        attridf['NoiseLevel'][i] = str(eval(attridf['NoiseLevel'][i]))
        
for i in range(len(attridf['WiFi'])):
    if str(attridf['WiFi'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['WiFi'][i]=str(eval(strinfo.sub('\'',str(attridf['WiFi'][i]))))
    elif str(attridf['WiFi'][i]).startswith('\''):
        attridf['WiFi'][i] = str(eval(attridf['WiFi'][i]))
        
for i in range(len(attridf['BYOBCorkage'])):
    if str(attridf['BYOBCorkage'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['BYOBCorkage'][i]=str(eval(strinfo.sub('\'',str(attridf['BYOBCorkage'][i]))))
    elif str(attridf['BYOBCorkage'][i]).startswith('\''):
        attridf['BYOBCorkage'][i] = str(eval(attridf['BYOBCorkage'][i]))
        
for i in range(len(attridf['Smoking'])):
    if str(attridf['Smoking'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['Smoking'][i]=str(eval(strinfo.sub('\'',str(attridf['Smoking'][i]))))
    elif str(attridf['Smoking'][i]).startswith('\''):
        attridf['Smoking'][i] = str(eval(attridf['Smoking'][i]))        
        
for i in range(len(attridf['AgesAllowed'])):
    if str(attridf['AgesAllowed'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['AgesAllowed'][i]=str(eval(strinfo.sub('\'',str(attridf['AgesAllowed'][i]))))
    elif str(attridf['AgesAllowed'][i]).startswith('\''):
        attridf['AgesAllowed'][i] = str(eval(attridf['AgesAllowed'][i]))
        
for i in range(len(attridf['AgesAllowed'])):
    if str(attridf['AgesAllowed'][i]).startswith('u\''):
        strinfo=re.compile('u\'')
        attridf['AgesAllowed'][i]=str(eval(strinfo.sub('\'',str(attridf['AgesAllowed'][i]))))
    elif str(attridf['AgesAllowed'][i]).startswith('\''):
        attridf['AgesAllowed'][i] = str(eval(attridf['AgesAllowed'][i]))

# %%
#TODO:NaN change to None.
#ColumnNames=attridf.columns
'''
for i in ColumnNames:
    x for x in attridf[[i]]
'''
isNaN=pd.isnull(attridf)
attridf[pd.isnull(attridf)]='unknown'
#attridf

# %%
#Add Business ID in the data frame
businessIDs=[x['business_id'] for x in dat]
attridf['business_id']=businessIDs
#attridf

# %%
attridf2 = copy.deepcopy(attridf)

# %%
col=[x.upper() for x in attridf2.columns.values]
col[len(col)-1]=col[len(col)-1].lower()

# %%
attridf2.columns=list(col)
attridf2
# Out:
#        ACCEPTSINSURANCE AGESALLOWED        ALCOHOL AMBIENCE     BYOB  \
# 0               unknown     unknown        unknown  unknown  unknown
# 1               unknown     unknown  beer_and_wine  unknown  unknown
# 2               unknown     unknown  beer_and_wine  unknown  unknown
# 3               unknown     unknown        unknown  unknown  unknown
# 4               unknown     unknown        unknown  unknown  unknown
# 5               unknown     unknown        unknown  unknown  unknown
# 6               unknown     unknown        unknown  unknown  unknown
# 7                 False     unknown        unknown  unknown  unknown
# 8               unknown     unknown        unknown  unknown  unknown
# 9               unknown     unknown           none  unknown  unknown
# 10              unknown     unknown  beer_and_wine  unknown  unknown
# 11              unknown     unknown           none     None  unknown
# 12              unknown     unknown        unknown  unknown  unknown
# 13              unknown     unknown        unknown  unknown  unknown
# 14              unknown     unknown       full_bar  unknown  unknown
# 15              unknown     unknown        unknown  unknown  unknown
# 16                 True     unknown        unknown  unknown  unknown
# 17              unknown     unknown        unknown  unknown  unknown
# 18              unknown     unknown        unknown  unknown  unknown
# 19              unknown     unknown       full_bar  unknown  unknown
# 20              unknown     unknown        unknown  unknown  unknown
# 21              unknown     unknown  beer_and_wine  unknown  unknown
# 22              unknown     unknown        unknown  unknown  unknown
# 23              unknown     unknown        unknown  unknown  unknown
# 24              unknown     unknown        unknown  unknown  unknown
# 25              unknown     unknown        unknown  unknown  unknown
# 26              unknown     unknown        unknown  unknown  unknown
# 27              unknown     unknown       full_bar  unknown  unknown
# 28              unknown     unknown        unknown  unknown  unknown
# 29              unknown     unknown        unknown  unknown  unknown
# ...                 ...         ...            ...      ...      ...
# 154576          unknown     unknown           none  unknown  unknown
# 154577          unknown     unknown        unknown  unknown  unknown
# 154578          unknown     unknown        unknown  unknown  unknown
# 154579          unknown     unknown        unknown  unknown  unknown
# 154580          unknown     unknown        unknown  unknown  unknown
# 154581          unknown     unknown        unknown  unknown  unknown
# 154582          unknown     unknown       full_bar  unknown  unknown
# 154583          unknown     unknown        unknown  unknown  unknown
# 154584          unknown     unknown        unknown  unknown  unknown
# 154585          unknown     unknown        unknown  unknown  unknown
# 154586          unknown     unknown           none  unknown  unknown
# 154587          unknown     unknown        unknown  unknown  unknown
# 154588          unknown     unknown  beer_and_wine  unknown  unknown
#        BUSINESSACCEPTSCREDITCARDS     ...       TRENDY  TUESDAY  UPSCALE  \
# 0                         unknown     ...      unknown  unknown  unknown
# 1                            True     ...        False  unknown    False
# 2                            True     ...        False  unknown    False
# 3                            True     ...      unknown  unknown  unknown
# 4                         unknown     ...      unknown  unknown  unknown
# 5                            True     ...      unknown  unknown  unknown
# 6                            True     ...      unknown  unknown  unknown
# 7                            True     ...      unknown  unknown  unknown
# 8                         unknown     ...      unknown  unknown  unknown
# 9                            True     ...        False  unknown    False
# 10                           True     ...        False    False    False
# 11                           True     ...      unknown  unknown  unknown
# 12                           True     ...      unknown  unknown  unknown
# 13                        unknown     ...      unknown  unknown  unknown
# 14                           True     ...        False  unknown    False
# 15                           True     ...      unknown  unknown  unknown
# 16                        unknown     ...      unknown  unknown  unknown
# 17                        unknown     ...      unknown  unknown  unknown
# 18                           True     ...      unknown  unknown  unknown
# 19                           True     ...        False  unknown    False
# 20                           True     ...        False  unknown    False
# 21                           True     ...        False  unknown    False
# 22                        unknown     ...      unknown  unknown  unknown
# 23                        unknown     ...      unknown  unknown  unknown
# 24                           True     ...      unknown  unknown  unknown
# 25                           True     ...      unknown  unknown  unknown
# 26                           True     ...      unknown  unknown  unknown
# 27                        unknown     ...        False  unknown    False
# 28                           True     ...      unknown  unknown  unknown
# 29                           True     ...      unknown  unknown  unknown
# ...                           ...     ...          ...      ...      ...
# 154576                    unknown     ...        False  unknown    False
# 154577                       True     ...      unknown  unknown  unknown
# 154578                       True     ...      unknown  unknown  unknown
# 154579                       True     ...      unknown  unknown  unknown
# 154580                       True     ...      unknown  unknown  unknown
# 154581                       True     ...      unknown  unknown  unknown
# 154582                       True     ...        False  unknown    False
# 154583                      False     ...      unknown  unknown  unknown
# 154584                    unknown     ...      unknown  unknown  unknown
# 154585                    unknown     ...      unknown  unknown  unknown
# 154586                    unknown     ...        False  unknown    False
# 154587                       True     ...      unknown  unknown  unknown
# 154588                       True     ...        False  unknown    False
# 154589                       True     ...      unknown  unknown  unknown
# 154590                       True     ...        False  unknown    False
# 154591                       True     ...      unknown  unknown  unknown
# 154592                    unknown     ...      unknown  unknown  unknown
# 154593                    unknown     ...        False  unknown    False
# 154594                    unknown     ...        False  unknown    False
# 154595                    unknown     ...      unknown  unknown  unknown
# 154596                    unknown     ...        False  unknown    False
# 154597                       True     ...      unknown  unknown  unknown
# 154598                       True     ...      unknown  unknown  unknown
# 154599                       True     ...      unknown  unknown  unknown
# 154600                       True     ...      unknown  unknown  unknown
# 154601                       True     ...        False  unknown     True
# 154602                       True     ...      unknown  unknown  unknown
# 154603                       True     ...      unknown  unknown  unknown
# 154604                      False     ...      unknown  unknown  unknown
# 154605                    unknown     ...      unknown  unknown  unknown
#
#           VALET VALIDATED    VEGAN VEGETARIAN    VIDEO WEDNESDAY business_id
# 0       unknown   unknown  unknown    unknown  unknown   unknown        3157
# 1         False     False  unknown    unknown  unknown   unknown       23732
# 2         False     False  unknown    unknown  unknown   unknown       53580
# 3       unknown   unknown  unknown    unknown  unknown   unknown       27909
# 4         False     False  unknown    unknown  unknown   unknown       95694
# 5       unknown   unknown  unknown    unknown  unknown   unknown       72533
# 6         False     False  unknown    unknown  unknown   unknown        5438
# 7         False     False  unknown    unknown  unknown   unknown      191639
# 8         False     False  unknown    unknown  unknown   unknown       74441
# 9         False     False  unknown    unknown  unknown   unknown       50474
# 10        False     False  unknown    unknown    False     False      126227
# 11      unknown   unknown  unknown    unknown  unknown   unknown      177055
# 12        False     False  unknown    unknown  unknown   unknown       31395
# 13        False     False  unknown    unknown  unknown   unknown       26363
# 14        False     False  unknown    unknown  unknown   unknown       93176
# 15      unknown   unknown  unknown    unknown  unknown   unknown      122404
# 16      unknown   unknown  unknown    unknown  unknown   unknown      104170
# 17      unknown   unknown  unknown    unknown  unknown   unknown      102554
# 18      unknown   unknown  unknown    unknown  unknown   unknown       98987
# 19         True     False  unknown    unknown    False   unknown       91868
# 20        False     False  unknown    unknown  unknown   unknown       24340
# 21        False     False  unknown    unknown  unknown   unknown      143668
# 22        False     False  unknown    unknown  unknown   unknown       46345
# 23        False     False  unknown    unknown  unknown   unknown      183592
# 24      unknown   unknown  unknown    unknown  unknown   unknown      154719
# 25        False     False  unknown    unknown  unknown   unknown       35759
# 26        False     False  unknown    unknown  unknown   unknown      165804
# 27        False     False  unknown    unknown  unknown   unknown      109616
# 28        False     False  unknown    unknown  unknown   unknown      191753
# 29      unknown   unknown  unknown    unknown  unknown   unknown      157718
# ...         ...       ...      ...        ...      ...       ...         ...
# 154576    False     False  unknown    unknown  unknown   unknown      107843
# 154577    False     False  unknown    unknown  unknown   unknown       24309
# 154578    False     False  unknown    unknown  unknown   unknown      142611
# 154579  unknown   unknown  unknown    unknown  unknown   unknown       29678
# 154580  unknown   unknown  unknown    unknown  unknown   unknown      126081
# 154581  unknown   unknown  unknown    unknown  unknown   unknown        4604
# 154582    False     False  unknown    unknown  unknown   unknown       38738
# 154583  unknown   unknown  unknown    unknown  unknown   unknown      150002
# 154584    False     False  unknown    unknown  unknown   unknown       43651
# 154585    False     False  unknown    unknown  unknown   unknown       76702
# 154586    False     False  unknown    unknown  unknown   unknown       18543
# 154587  unknown   unknown  unknown    unknown  unknown   unknown      182280
# 154588    False     False  unknown    unknown  unknown   unknown      155035
# 154589  unknown   unknown  unknown    unknown  unknown   unknown       69940
# 154590    False     False  unknown    unknown  unknown   unknown      165834
# 154591    False     False  unknown    unknown  unknown   unknown       14816
# 154592    False     False  unknown    unknown  unknown   unknown      143725
# 154593    False     False  unknown    unknown  unknown   unknown      151704
# 154594    False     False  unknown    unknown  unknown   unknown       10509
# 154595  unknown   unknown  unknown    unknown  unknown   unknown      130428
# 154596  unknown   unknown  unknown    unknown  unknown   unknown      162304
# 154597  unknown   unknown  unknown    unknown  unknown   unknown       92287
# 154598    False     False  unknown    unknown  unknown   unknown       88965
# 154599  unknown   unknown  unknown    unknown  unknown   unknown      138869
# 154600     True     False  unknown    unknown  unknown   unknown      168152
# 154601    False     False  unknown    unknown  unknown   unknown       15204
# 154602  unknown   unknown  unknown    unknown  unknown   unknown       77293
# 154603  unknown   unknown  unknown    unknown  unknown   unknown      106254
# 154604    False     False  unknown    unknown  unknown   unknown      134131
# 154605  unknown   unknown  unknown    unknown  unknown   unknown      144164
#
# [154606 rows x 89 columns]

# %%
DataFrame.to_csv(attridf2,"business_train_kaggle.csv",index=False)

# %%
#DataFrame.to_csv(pd.DataFrame(col),"business_train_kaggle_2_colnames.csv",index=False)
