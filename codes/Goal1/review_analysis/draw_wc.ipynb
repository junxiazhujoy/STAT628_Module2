# %%
import pandas as pd
import numpy as np
import csv
import os
import re
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df_star1 = pd.read_csv('df_star1.csv')
df_star2 = pd.read_csv('df_star2.csv')
df_star3 = pd.read_csv('df_star3.csv')
df_star4 = pd.read_csv('df_star4.csv')
df_star5 = pd.read_csv('df_star5.csv')

# %%
df_star1.head(10)
# Out:
#      words  frequency
# 0     food      20929
# 1       no      17211
# 2  service      15964
# 3    would      15557
# 4      get      14431
# 5      one      13774
# 6     like      13267
# 7  NOT_the      13037
# 8   NOT_to      12671
# 9     time      12140

# %%
dict_wc = df_star1.set_index('words').T.to_dict('int')['frequency']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud(background_color = 'White',width=400,height=300,scale=4,max_font_size=100)
wc.generate_from_frequencies(dict_wc)

plt.figure(figsize=(20,12), dpi=1200)
plt.imshow(wc)
plt.axis("off")
plt.show()
